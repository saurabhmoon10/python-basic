# %% [markdown]
# # Condition

# %% [markdown]
# The condition can be coded or written inside the if ,elif ,else blocks.
#
# These if,elif,else are the keywords of python.
#
# python is simple , easy because it is an english scripting language.

# %%
# import is an keyword used to import or attached the package of module in a program.

# random is an package (group of program or a module)

# here we have uses 'randint' which is an module of package random 
# uses to print the random integer values.
import random
rand_var=random.randint(1,20)

print(rand_var)
print()
guess=int(input("Enter the number\n"))
print()
#using if else functions.
if guess == rand_var:
    print("The guess number matched with random number successfully.")
    
else:
    print("The guess number doesn't matched with the random number\nplease keep trying..")
# Out:
# 5
#
# Enter the number
# 5
#
# The guess number matched with random number successfully.

# %%
# Bike milege performance

bike_name=input("Enter your bike name\n")

print()
avg_mileage=int(input("enter the rough value of your bike milege\n"))
print()

if avg_mileage <=100 and avg_mileage >=91:
    print("The mileage ",avg_mileage,"Kmpl is Great")
    print("bike doesn't required to get serviced at this point.")
    
elif avg_mileage <=90 and  avg_mileage > 75:
    print("The mileage",avg_mileage,"kmpl is good")
    print("Need to ride in smooth\nDon't do rash driving.")

elif avg_mileage<=75 and avg_mileage >= 50:
    print("The mileage",avg_mileage,"kmpl is weak")
    print("Better to check ones in a service center.")
    
else:
    print("The mileage",avg_mileage,"kmpl is low")
    print("Bike need to be get serviced as soon as possible ")
# Out:
# Enter your bike name
# gt100
#
# enter the rough value of your bike milege
# 100
#
# The mileage  100 Kmpl is Great
# bike doesn't required to get serviced at this point.

# %%
# magician mystery game:-


a=eval(input("Take a  number from 1 to 10 \n"))

b=eval(input("ask one  even number from your friend\n"))

c=eval(input("magician gives the number\n"))

if (((a+b+c)/2)-b) == c/2:
    print("Number inside your mind is ",(c/2))
    print("HURRY!!!\nThe magician mystery is solved...")
    
    
else :
    print("Mystery Not Solved\nBetter luck next time")
# Out:
# Take a  number from 1 to 10
# 5
# ask one  even number from your friend
# 5
# magician gives the number
# 10
# Number inside your mind is  5.0
# HURRY!!!
# The magician mystery is solved...

# %%
# Categories of the players based on their todays match:-


player_name=input("Enter the player name \n")
hit_runs=int(input("enter the run\n"))
wicket_taken=int(input("Enter the wicket taken\n"))
print()
print("Player Name\truns\twicket_Taken")
print()
if hit_runs >100 and hit_runs <200 or wicket_taken>=3:
    print(player_name,"\t",hit_runs,"\t",wicket_taken)
    print("Elite Scorer")
    
elif hit_runs==100:
    print(player_name,'\t',hit_runs)
    print("Century Club")
    
elif hit_runs<100 and hit_runs>=80:
    print(player_name,"\t",hit_runs,"\t",wicket_taken)
    print("Run machine")
    
elif hit_runs <=79 and hit_runs >= 55 or wicket_taken<=3:
    print(player_name,'\t',hit_runs,'\t',wicket_taken)
    print("Emerging players")
    
elif hit_runs ==50 and hit_runs<54:
    print(player_name,'\t',hit_runs,"\t",wicket_taken)
    print("Half-Century Hitter")
    
    
elif hit_runs <55 and hit_runs >= 1:
    print(player_name,'\t',hit_runs,'\t',wicket_taken)
    print("Scoring Progression")
    
else:
    print(player_name,'\t',hit_runs)
    print("Keep working hard")

# %%
# these code is not completed please complete it in proper manner.
# mobile phone suggestor code !!!

print("Mobile Guru!!!\n")
salary=int(input("Please..enter your salary\n"))
print()
investing_price=int(input("Enter the amount\n"))
print()
if salary > 100000 and salary <=150000:
    if investing_price >=100000 and investing_price <=140000:
        print("You have again two choices")
        print("(1)Go for samsung xyz\n(2)Go for iphone- 13")
    
    
        
    elif investing_price<=99999 and investing_price >=65000:
        print("You have again more best choices to go for")
        print("(1)iphone-12 max\n(2) vivo-xyz \n(3)Oppo reno-14\n(4)Mi-ultra xyz")
        

    else:
        print("Wait for few day to explore the new arrivals please...")
        
elif salary >=75000 and salary <=100000:
    if investing_price >=45000 and investing_price<=64000:
        print("You have list of choice to go for :-")
        print("(1)Samsung-xyz\(2)Vivo-max\n(3)Oppo\n(4)iphone-11")
        
    elif investing_price<=44999 and investing_price>=30000:
        print("Best phone are listed below....")
        print("(1)Samsung-21\n(2)lenovo-98\n(3)poco-p1\n(4)moto-m25")
        
    else:
        print("Got confuse\n Don't worry festive seasons are coming. ")
        
else:
    print("Waiting for new launches ")

# %%
# if we have 100 cc bike and daily routine is almost 50 kmpl find its  monthly average and cost of service 
# HOME WORK QUESTION:-

# %%
bike_name=input("Enter the bike name\n")
bike_cc=int(input("Enter the CC of bike\n"))
daily_bike_run=int(input("Enter the daily kms"))
day=int(input("enter the number of working days\n"))
fuel_consumed=int(input("Enter the  fuel filled in whole month"))

if bike_cc >=500 and bike_cc<=1000:
    bike_avg=(daily_bike_run*day)/fuel_consumed
    print("Bike avg-",bike_avg)
# Out:
# Enter the bike name
# zx10r
# Enter the CC of bike
# 1000
# Enter the daily kms50
# enter the number of working days
# 20
# Enter the  fuel filled in whole month60
# Bike avg- 16.666666666666668

# %%
# voting validator 


Age=int(input("Enter your age\n"))
print()
citizenship=input("Are you the citizen of country?\n(yes/no)\n")
print()
if Age <18 and citizenship=='yes':
    print("Your still under age.")
    
if Age<18 and citizenship!='yes':
    print("You are not eligible for voting.")
    
elif Age >=18 and Age<=30:
    if citizenship=='yes':
        print("Your eligible for voting.")
        print("under Youth category")
        
    elif citizenship!='yes':
        print('Your are not eligible for voting')
        print("As your not the citizen of our country")

elif Age >=31 and Age<50:
    if citizenship=='yes':
        print("You are eligible for voting\nunder Middle-Aged Category")
        
    else:
        print("oops,you are not eligible")
else:
    if citizenship=='yes':
        print("You are eligible  for voting\n under senior-citizen category")
        
    else:
        print("Though you are senior-citizen\nBut you are not eligible for voting in our country.")
# Out:
# Enter your age
# 21
#
# Are you the citizen of country?
# (yes/no)
# yes
#
# Your eligible for voting.
# under Youth category

# %%
price=int(input("enter the amount\n"))
if price>500:
    print("you have various options")
    if price >=1200 and price<=1500:
        print("You can buy combo of  2 shirts ,1 jeans and 1 jacket ")
        
    elif price <=1199 and price>=999:
        print("You can buy the combo of(1)3 shirts\nor\n(2)2-chinos\nor\n(3)1-hoodie and 1-jeans")
        
    else:
        print("you can buy\n(1)2-jacket\nor\n(2)1-jeans and 2-shirt")
        
elif price <500:
    if price<=499 and price>=250:
        print("You can buy\n(1)Sweatshirt\nor\(2)trouser\nor\n(3)cotton-shirt")
        
    elif price<=249 and price >=100:
        print("you can buy\n(1)t-shirts\nor\n(2)shorts")
    else:
        print("you can buy the socks")
        
else:
    print("Wait for coming festive season to explore more")
# Out:
# enter the amount
# 0
# you can buy the socks

# %%
#JEE module
# yet not complete please finished it as soon as possible.

marks=int(input("Enter your obtained marks\n"))
        
if marks == 300:
    print("You can get IIIT")
    
elif marks >=200 and marks<=299:
    if marks >270:
        print("you can get IITs")
        
    elif marks > 250:
        print("you can get NITs")
        
    elif marks >200:
        print("you can get university top Rank collegs")
        
elif marks >=0 and marks<=199:
    if marks>150:
        print("you can get University based colleges")
        
    elif marks >50:
        print("you can go for private university")
    
    elif marks >=0:
        print("you should take a one more try")
        
elif marks <0:
    print("Negative marks\nbetter luck next time")
        
else:
    print("300 is the last range of marks")
# Out:
# Enter your obtained marks
# 65
# you can go for private university

# %%
# write a code for a net_salary,gross_salary,bonus,experience of working ,retirement of employee,employee-id
# promotion based on experience
#yearly increament in percentage on salary of employee.
#deduction of salary

employee_id=input("enter your  employee-id(tcs2023)\n")
print()


#deduction_amount=gross_salary - net_salary
#print("Deduction amount =",deduction_amount)


print()
if len(employee_id)==7:
    print("Employee-id =",employee_id)
    
    age=int(input("Enter your age\n"))
    print()

    gender=input("Enter the gender (m/f)\n")
    print()

    year_of_experience=eval(input("Enter the year of expereince\n"))
    print()

    basic_salary=int(input("enter your basic salary\n"))
    print()

    salary_increment_rate=eval(input("enter increment rate\n"))
    print()

    gross_salary = basic_salary * (1 + salary_increment_rate * year_of_experience)
    gross_salary = int(gross_salary)
    net_salary = gross_salary - (basic_salary*0.15)
    net_salary = int(net_salary)
    print("gross_salary -", gross_salary)
    print("net_salary -", net_salary)
    print()
    
    #deduction_amount=gross_salary - net_salary
    #print("Deduction amount of{employee_id} =",deduction_amount)
    
    if year_of_experience >=10 :
        if gender=='f':
            bonus_rate=0.2
            bonus=net_salary*bonus_rate
            print("Bouns amount =",bonus)
            if year_of_experience >15 or age >=56:
                if age>=56 and age<=59:
                    print("Employee is eligible for VR criteria.")
                elif age ==60:
                    print("congratulation!!!\n you are going to get retire soon.")
                
            elif year_of_experience >15 and net_salary>=100000:
                additional_bonus=10000
                total_bonus=bonus+additional_bonus
                print("Overall bonus \n",(bonus),"+",(additional_bonus),"=",int(total_bonus))
                print("You will get early promotion!!!")
                print("and a personal cabin")
            elif year_of_experience <15 and net_salary>=80000:
                additional_bonus=5000
                total_bonus=bonus+additional_bonus
                print("Overall bonus\n",(bonus),"+",(additional_bonus),"=",int(total_bonus))
                print("You will get promoted to executive level")
            elif age>=55 and age<=59:
                print("you eligible for VR")
                
            else:
                if age==60:
                    print("you are going to get your retirement")
                    
        elif gender=='m':
            bonus_rate=0.18
            bonus=net_salary*bonus_rate
            print("Bonus amount =",bonus)
            if year_of_experience >15 or age>56:
                if age>=57 and age<59:
                    print("You are now eligible to take your VR.")
                elif age==60:
                    print("Congratulation!!!\nyour about to get your retirement.")
                    
            elif year_of_experience >15 and net_salary>=100000:
                additional_bonus=9500
                total_bonus=bonus+additional_bonus
                print("Overall bonus \n",(bonus),"+",(additional_bonus),"=",int(total_bonus))
                print("You will get early promotion!!!")
                print("and a personal cabin")
                
            elif year_of_experience <15 and net_salary>=80000:
                additional_bonus=4500
                total_bonus=bonus+additional_bonus
                print("Overall bonus\n",(bonus),"+",(additional_bonus),"=",int(total_bonus))
                print("You will get promoted to executive level")
                
    elif year_of_experience >=6 <10:
        if gender=='f':
            bonus_rate=0.15
            bonus=net_salary * bonus_rate
            print("Bonus payout =",int(bonus))
            if net_salary >=40000 and age>=28 < 30:
                additional_bonus=3500
                total_bonus=bonus + additional_bonus
                print("Overall bonus pay =",bonus,"+",additional_bonus,"=",int(total_bonus))
                print()
                print("you are going to be promoted early.")
            elif age>=30:
                print("you are going to be promoted as senior employee.")
                
                
        elif gender=='m':
            bonus_rate=0.12
            bonus=net_salary*bonus_rate
            print("Bonus payout =",int(bonus))
            if net_salary >45000 and age>=28 < 35:
                additional_bonus= 4000
                total_bonus=additional_bonus+bonus
                print("Overall bonus pay =",bonus,"+",additional_bonus,"=",total_bonus)
                print()
                print("you are going to be promoted early.")
            elif age >=35:
                print("you are going to be promoted as senior employee.")
                
                
    elif year_of_experience >2 <=5:
        if gender=='f':
            bouns_rate=0.10
            bonus=net_salary * bouns_rate
            print("Bonus payout =",int(bonus))
            if gross_salary>=40000:
                print("Get regularization")
                
            elif net_salary >=35000:
                print("get early regularization")
            
        elif gender=='m':
            bouns_rate=0.8
            bonus=net_salary * bonus_rate
            print("Bonus pay =",int(bonus))
            if gross_salary>=42000:
                print("Get regularization")
            elif net_salary >=37000:
                print("Get early regularization")
                
            
                
         
    else:
        print("No bonus for employee.")

     
        

    
    



    
else :
    if len(employee_id)!=7:
        print("You entered the invalid employee-id ")
        print("Please try again later !!!")
# Out:
# enter your  employee-id(tcs2023)
# wcl2023
#
#
# Employee-id = wcl2023
# Enter your age
# 58
#
# Enter the gender (m/f)
# f
#
# Enter the year of expereince
# 27
#
# enter your basic salary
# 30000
#
# enter increment rate
# 0.20
#
# gross_salary - 192000
# net_salary - 187500
#
# Bouns amount = 37500.0
# Employee is eligible for VR criteria.

# %%
num=int(input("Enter the number\n"))
flag=False
if num ==1:
    print(num,"is not a prime number.")
    

        
elif num>1:
    for i in range(2,num):
        if (num%i==0):
            flag=True
            break
    if flag:
        print(num,"is not a prime number")
    else:
        print(num,"is a prime number")
# Out:
# Enter the number
# 2
# 2 is a prime number

# %% [markdown]
# #
